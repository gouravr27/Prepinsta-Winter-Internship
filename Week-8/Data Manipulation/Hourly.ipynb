# %% [markdown]
# # Hourly Dataset

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading Datsets

# %% [markdown]
# * Loading Hourly Steps file

# %%
h1=pd.read_csv("/content/hourlySteps_merged.csv")
h1.head()
# Out:
#            Id           ActivityHour  StepTotal
# 0  1503960366  4/12/2016 12:00:00 AM        373
# 1  1503960366   4/12/2016 1:00:00 AM        160
# 2  1503960366   4/12/2016 2:00:00 AM        151
# 3  1503960366   4/12/2016 3:00:00 AM          0
# 4  1503960366   4/12/2016 4:00:00 AM          0

# %% [markdown]
# * Loading Hourly Calories file

# %%
h2=pd.read_csv("/content/hourlyCalories_merged.csv")
h2.head()
# Out:
#            Id           ActivityHour  Calories
# 0  1503960366  4/12/2016 12:00:00 AM        81
# 1  1503960366   4/12/2016 1:00:00 AM        61
# 2  1503960366   4/12/2016 2:00:00 AM        59
# 3  1503960366   4/12/2016 3:00:00 AM        47
# 4  1503960366   4/12/2016 4:00:00 AM        48

# %% [markdown]
# * Merging both Hourly Stpes and Calories files

# %%
merge=pd.merge(h1,h2, on=['Id','ActivityHour'], how='left')
merge.head()
# Out:
#            Id           ActivityHour  StepTotal  Calories
# 0  1503960366  4/12/2016 12:00:00 AM        373        81
# 1  1503960366   4/12/2016 1:00:00 AM        160        61
# 2  1503960366   4/12/2016 2:00:00 AM        151        59
# 3  1503960366   4/12/2016 3:00:00 AM          0        47
# 4  1503960366   4/12/2016 4:00:00 AM          0        48

# %% [markdown]
# * Loading Hourly Intensities file

# %%
h3=pd.read_csv("/content/hourlyIntensities_merged.csv")
h3.head()
# Out:
#            Id           ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366  4/12/2016 12:00:00 AM              20          0.333333
# 1  1503960366   4/12/2016 1:00:00 AM               8          0.133333
# 2  1503960366   4/12/2016 2:00:00 AM               7          0.116667
# 3  1503960366   4/12/2016 3:00:00 AM               0          0.000000
# 4  1503960366   4/12/2016 4:00:00 AM               0          0.000000

# %% [markdown]
# * Merging both previously merged file and Hourly Intensities file

# %%
hour_data_merge=pd.merge(merge,h3, on=['Id','ActivityHour'], how='left')
hour_data_merge.head()
# Out:
#            Id           ActivityHour  StepTotal  Calories  TotalIntensity  \
# 0  1503960366  4/12/2016 12:00:00 AM        373        81              20
# 1  1503960366   4/12/2016 1:00:00 AM        160        61               8
# 2  1503960366   4/12/2016 2:00:00 AM        151        59               7
# 3  1503960366   4/12/2016 3:00:00 AM          0        47               0
# 4  1503960366   4/12/2016 4:00:00 AM          0        48               0
#
#    AverageIntensity
# 0          0.333333
# 1          0.133333
# 2          0.116667
# 3          0.000000
# 4          0.000000

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# * Now we split the **ActivityHour** column into two seperate colums **Activity_Date** and **Activity_Hour**

# %%
hour_data_merge[['Activity_Date','Activity_Hour']]= hour_data_merge['ActivityHour'].str.split(' ', 1, expand=True)
hour_data_merge.tail()
# Out:
# <ipython-input-7-99be624c652b>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   hour_data_merge[['Activity_Date','Activity_Hour']]= hour_data_merge['ActivityHour'].str.split(' ', 1, expand=True)
#                Id           ActivityHour  StepTotal  Calories  TotalIntensity  \
# 22094  8877689391  5/12/2016 10:00:00 AM        514       126              12
# 22095  8877689391  5/12/2016 11:00:00 AM       1407       192              29
# 22096  8877689391  5/12/2016 12:00:00 PM       3135       321              93
# 22097  8877689391   5/12/2016 1:00:00 PM        307       101               6
# 22098  8877689391   5/12/2016 2:00:00 PM        457       113               9
#
#        AverageIntensity Activity_Date Activity_Hour
# 22094          0.200000     5/12/2016   10:00:00 AM
# 22095          0.483333     5/12/2016   11:00:00 AM
# 22096          1.550000     5/12/2016   12:00:00 PM
# 22097          0.100000     5/12/2016    1:00:00 PM
# 22098          0.150000     5/12/2016    2:00:00 PM

# %% [markdown]
# * Now we will drop the **ActivityHour** Column as we split it, so we don't need this column now.

# %%
hour_data_merge.drop(['ActivityHour'], axis=1)
# Out:
#                Id  StepTotal  Calories  TotalIntensity  AverageIntensity  \
# 0      1503960366        373        81              20          0.333333
# 1      1503960366        160        61               8          0.133333
# 2      1503960366        151        59               7          0.116667
# 3      1503960366          0        47               0          0.000000
# 4      1503960366          0        48               0          0.000000
# ...           ...        ...       ...             ...               ...
# 22094  8877689391        514       126              12          0.200000
# 22095  8877689391       1407       192              29          0.483333
# 22096  8877689391       3135       321              93          1.550000
# 22097  8877689391        307       101               6          0.100000
# 22098  8877689391        457       113               9          0.150000
#
#       Activity_Date Activity_Hour
# 0         4/12/2016   12:00:00 AM
# 1         4/12/2016    1:00:00 AM
# 2         4/12/2016    2:00:00 AM
# 3         4/12/2016    3:00:00 AM
# 4         4/12/2016    4:00:00 AM
# ...             ...           ...
# 22094     5/12/2016   10:00:00 AM
# 22095     5/12/2016   11:00:00 AM
# 22096     5/12/2016   12:00:00 PM
# 22097     5/12/2016    1:00:00 PM
# 22098     5/12/2016    2:00:00 PM
#
# [22099 rows x 7 columns]

# %% [markdown]
# * Now we will changed the column order

# %%
hour_data_merge=hour_data_merge[['Id','Activity_Date','Activity_Hour','StepTotal','Calories','TotalIntensity','AverageIntensity']]

# %%
hour_data_merge.rename(columns = {'StepTotal':'Step_Total', 'TotalIntensity':'Total_Intensity',
                              'AverageIntensity':'Average_Intensity'})
# Out:
#                Id Activity_Date Activity_Hour  Step_Total  Calories  \
# 0      1503960366     4/12/2016   12:00:00 AM         373        81
# 1      1503960366     4/12/2016    1:00:00 AM         160        61
# 2      1503960366     4/12/2016    2:00:00 AM         151        59
# 3      1503960366     4/12/2016    3:00:00 AM           0        47
# 4      1503960366     4/12/2016    4:00:00 AM           0        48
# ...           ...           ...           ...         ...       ...
# 22094  8877689391     5/12/2016   10:00:00 AM         514       126
# 22095  8877689391     5/12/2016   11:00:00 AM        1407       192
# 22096  8877689391     5/12/2016   12:00:00 PM        3135       321
# 22097  8877689391     5/12/2016    1:00:00 PM         307       101
# 22098  8877689391     5/12/2016    2:00:00 PM         457       113
#
#        Total_Intensity  Average_Intensity
# 0                   20           0.333333
# 1                    8           0.133333
# 2                    7           0.116667
# 3                    0           0.000000
# 4                    0           0.000000
# ...                ...                ...
# 22094               12           0.200000
# 22095               29           0.483333
# 22096               93           1.550000
# 22097                6           0.100000
# 22098                9           0.150000
#
# [22099 rows x 7 columns]

# %%
hour_data_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22099 entries, 0 to 22098
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                22099 non-null  int64
#  1   Activity_Date     22099 non-null  object
#  2   Activity_Hour     22099 non-null  object
#  3   StepTotal         22099 non-null  int64
#  4   Calories          22099 non-null  int64
#  5   TotalIntensity    22099 non-null  int64
#  6   AverageIntensity  22099 non-null  float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 1.3+ MB

# %% [markdown]
# * Now we will change the data type of Activity_Date column to Date data type

# %%
hour_data_merge['Activity_Date'] = pd.to_datetime(hour_data_merge['Activity_Date'].str.strip())

# %%
hour_data_merge.head()
# Out:
#            Id Activity_Date Activity_Hour  StepTotal  Calories  \
# 0  1503960366    2016-04-12   12:00:00 AM        373        81
# 1  1503960366    2016-04-12    1:00:00 AM        160        61
# 2  1503960366    2016-04-12    2:00:00 AM        151        59
# 3  1503960366    2016-04-12    3:00:00 AM          0        47
# 4  1503960366    2016-04-12    4:00:00 AM          0        48
#
#    TotalIntensity  AverageIntensity
# 0              20          0.333333
# 1               8          0.133333
# 2               7          0.116667
# 3               0          0.000000
# 4               0          0.000000

# %%
hour_data_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22099 entries, 0 to 22098
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                22099 non-null  int64
#  1   Activity_Date     22099 non-null  datetime64[ns]
#  2   Activity_Hour     22099 non-null  object
#  3   StepTotal         22099 non-null  int64
#  4   Calories          22099 non-null  int64
#  5   TotalIntensity    22099 non-null  int64
#  6   AverageIntensity  22099 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# * Round off the AverageIntensity values

# %%
hour_data_merge['AverageIntensity'] = np.round(hour_data_merge['AverageIntensity'],decimals = 2)
hour_data_merge.head()
# Out:
#            Id Activity_Date Activity_Hour  StepTotal  Calories  \
# 0  1503960366    2016-04-12   12:00:00 AM        373        81
# 1  1503960366    2016-04-12    1:00:00 AM        160        61
# 2  1503960366    2016-04-12    2:00:00 AM        151        59
# 3  1503960366    2016-04-12    3:00:00 AM          0        47
# 4  1503960366    2016-04-12    4:00:00 AM          0        48
#
#    TotalIntensity  AverageIntensity
# 0              20              0.33
# 1               8              0.13
# 2               7              0.12
# 3               0              0.00
# 4               0              0.00

# %%
hour_data_merge
# Out:
#                Id Activity_Date Activity_Hour  StepTotal  Calories  \
# 0      1503960366    2016-04-12   12:00:00 AM        373        81
# 1      1503960366    2016-04-12    1:00:00 AM        160        61
# 2      1503960366    2016-04-12    2:00:00 AM        151        59
# 3      1503960366    2016-04-12    3:00:00 AM          0        47
# 4      1503960366    2016-04-12    4:00:00 AM          0        48
# ...           ...           ...           ...        ...       ...
# 22094  8877689391    2016-05-12   10:00:00 AM        514       126
# 22095  8877689391    2016-05-12   11:00:00 AM       1407       192
# 22096  8877689391    2016-05-12   12:00:00 PM       3135       321
# 22097  8877689391    2016-05-12    1:00:00 PM        307       101
# 22098  8877689391    2016-05-12    2:00:00 PM        457       113
#
#        TotalIntensity  AverageIntensity
# 0                  20              0.33
# 1                   8              0.13
# 2                   7              0.12
# 3                   0              0.00
# 4                   0              0.00
# ...               ...               ...
# 22094              12              0.20
# 22095              29              0.48
# 22096              93              1.55
# 22097               6              0.10
# 22098               9              0.15
#
# [22099 rows x 7 columns]

# %%
hour_data_merge.to_csv("hourly_data.csv")
